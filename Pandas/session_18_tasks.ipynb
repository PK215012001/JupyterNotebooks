# %%
import numpy as np
import pandas as pd

# to visualize all the column, run the below code
#pd.options.display.max_columns = None
# to show all the records, use the below code
# pd.options.display.max_rows = None

# %% [markdown]
# ## Fifa Worldcup - 2022 dataset.
#
# You can find the dataset from [here](https://www.kaggle.com/datasets/sayanroy729/fifa-worldcup-2022-results).
#
# Also you can directly use an url to read the dataset by using `pd.read_csv()` method. Check the below code cell.

# %%
# To get the details about the dataset, please visit
# https://www.kaggle.com/datasets/sayanroy729/fifa-worldcup-2022-results

url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vT3D_x_4DS6d51LKJ7ze1sxT5WpV5uiSVOFYHLwBiGru6vFyVv5h5-83AwFjxWYiWfCDjDAaarHAV-k/pub?gid=0&single=true&output=csv"
df = pd.read_csv(url)
df.head()
# Out:
#    Sl. No  Match No.     Team      Against Group  Goal  Possession (%)  \
# 0       1          1    Qatar      Ecuador     A     0              40
# 1       2          1  Ecuador        Qatar     A     2              46
# 2       3          2  England         Iran     B     6              69
# 3       4          2     Iran      England     B     2              20
# 4       5          3  Senegal  Netherlands     A     0              39
#
#    Inside Penalty Area  Outside Penalty Area  Assists  ...  Fouls Against  \
# 0                    0                     0        0  ...             15
# 1                    2                     0        1  ...             15
# 2                    6                     0        6  ...              9
# 3                    2                     0        1  ...             14
# 4                    0                     0        0  ...             13
#
#    Offsides  Passes  Passes Completed  Crosses  Crosses Completed  Corners  \
# 0         3     453               387       10                  5        1
# 1         4     484               419       26                 10        3
# 2         2     810               733       29                  9        8
# 3         2     232               156       11                  3        0
# 4         2     391               326       22                  8        6
#
#    Free Kicks  Penalties Scored  Pts
# 0          19                 0    0
# 1          17                 1    3
# 2          16                 0    3
# 3          10                 1    0
# 4          14                 0    0
#
# [5 rows x 38 columns]

# %%
pd.options.display.max_columns = None

# %%
df.head(3)
# Out:
#    Sl. No  Match No.     Team  Against Group  Goal  Possession (%)  \
# 0       1          1    Qatar  Ecuador     A     0              40
# 1       2          1  Ecuador    Qatar     A     2              46
# 2       3          2  England     Iran     B     6              69
#
#    Inside Penalty Area  Outside Penalty Area  Assists  Total Attempts  \
# 0                    0                     0        0               5
# 1                    2                     0        1               5
# 2                    6                     0        6              13
#
#    On Target  Off Target  Target in Penalty  Target from Outside  \
# 0          0           5                  2                    3
# 1          5           2                  4                    1
# 2          7           3                 10                    3
#
#    Left Channel  Left Inside Channel  Central Channel  Right Inside Channel  \
# 0            15                    0                3                     1
# 1             8                    7                6                     4
# 2            11                    5                2                     3
#
#    Right Channel  Receptions MD  Receptions D  Attempted Line Breaks  \
# 0              9             45             5                    159
# 1              6             55            10                    159
# 2             11             72            15                    133
#
#    Completed Line Breaks  Attempted Defensive Line Breaks  \
# 0                    100                                6
# 1                    103                                6
# 2                     94                                8
#
#    Completed Defensive Line Breaks  Yellow Cards  Red Cards  Fouls Against  \
# 0                                4             4          0             15
# 1                                4             2          0             15
# 2                                6             0          0              9
#
#    Offsides  Passes  Passes Completed  Crosses  Crosses Completed  Corners  \
# 0         3     453               387       10                  5        1
# 1         4     484               419       26                 10        3
# 2         2     810               733       29                  9        8
#
#    Free Kicks  Penalties Scored  Pts
# 0          19                 0    0
# 1          17                 1    3
# 2          16                 0    3

# %% [markdown]
# ### `Q-1:` Use the football dataset. Find out the total percentages that each team made on target. Display the result as a python dictionary where the keys are the team list and the values are the percentage values. Round off the percentage values up to 2 decimal places.
#
# *Help:*
# - First, find out how many total teams are participated in this worldcup. For that, you can use `unique()` method on the column "Team" or "Against".
# - Loop through the teams list that you have found in previous section, and then filter the dataset according to that. After filtering the dataset, find out total attempts sum and total on target sum.
# - After getting these values, find out the percentage by total on target divided by total attempts and multiply by 100. And store to a python dictionary where the key will be the team name and the values will be the percentages.
# - At the end,sort the dictionary by the values (not by the keys) and print the result.

# %% [markdown]
# **Sample Output:**
# ```bash
# {'Costa Rica': 54.55,
#  'Cameroon': 51.85,
#  'Ecuador': 48.15,
#  'Argentina': 46.99,
#  'Brazil': 45.56,
#  'England': 45.0,
#  'Portugal': 40.32,
#  'Ghana': 40.0,
#  'Netherlands': 39.02,
#  'Korea Republic': 36.73,
#  'Australia': 36.0,
#  'Mexico': 34.88,
#  'Croatia': 34.78,
#  'Germany': 34.33,
#  'France': 32.97,
#  'Spain': 32.69,
#  'Belgium': 32.35,
#  'Serbia': 32.26,
#  'Iran': 31.43,
#  'Uruguay': 31.25,
#  'United States': 31.11,
#  'Saudi Arabia': 31.03,
#  'Senegal': 30.77,
#  'Denmark': 30.56,
#  'Switzerland': 30.56,
#  'Japan': 30.23,
#  'Wales': 29.17,
#  'Qatar': 28.57,
#  'Morocco': 28.3,
#  'Tunisia': 26.67,
#  'Poland': 25.0,
#  'Canada': 17.65}
# ```

# %%
# code here
temp = df.groupby('Team')[['On Target', 'Total Attempts']].sum()
temp['percentage'] = (temp['On Target'] / temp['Total Attempts']) * 100
temp.sort_values('percentage', ascending = False, inplace = True)

# %%
temp.reset_index(inplace = True)

# %%
temp.head()
# Out:
#          Team  On Target  Total Attempts  percentage
# 0  Costa Rica          6              11   54.545455
# 1    Cameroon         14              27   51.851852
# 2     Ecuador         13              27   48.148148
# 3   Argentina         48             104   46.153846
# 4      Brazil         41              90   45.555556

# %%
teams = {}
for i in range(temp.shape[0]):
    teams[temp['Team'].values[i]] = temp['percentage'].values[i]
teams
# Out:
# {'Costa Rica': 54.54545454545454,
#  'Cameroon': 51.85185185185185,
#  'Ecuador': 48.148148148148145,
#  'Argentina': 46.15384615384615,
#  'Brazil': 45.55555555555556,
#  'England': 45.0,
#  'Portugal': 40.32258064516129,
#  'Ghana': 40.0,
#  'Netherlands': 39.02439024390244,
#  'Korea Republic': 36.734693877551024,
#  'Australia': 36.0,
#  'Mexico': 34.883720930232556,
#  'France': 34.65346534653465,
#  'Germany': 34.32835820895522,
#  'Croatia': 33.734939759036145,
#  'Spain': 32.69230769230769,
#  'Belgium': 32.35294117647059,
#  'Serbia': 32.25806451612903,
#  'Iran': 31.428571428571427,
#  'Uruguay': 31.25,
#  'United States': 31.11111111111111,
#  'Saudi Arabia': 31.03448275862069,
#  'Senegal': 30.76923076923077,
#  'Switzerland': 30.555555555555557,
#  'Denmark': 30.555555555555557,
#  'Japan': 30.23255813953488,
#  'Wales': 29.166666666666668,
#  'Qatar': 28.57142857142857,
#  'Morocco': 28.333333333333332,
#  'Tunisia': 26.666666666666668,
#  'Poland': 25.0,
#  'Canada': 17.647058823529413}

# %% [markdown]
# ### `Q-2:` Find out how many times the teams are played in this Fifa Worldcup-2022. On top of this, find out the ranks of the teams.
#
# Note: The `DataFrame.rank()` method takes an optiinal parameter named `method`. This parameter takes different values, but one of them is `average` which is by-default. So, when you do the rank, you will get some 2.5 like floating values. But if you change the value as `first`, then you will get in integers but the datatype will be float. So, try with `method="first"` parameter.

# %%
# code here
df['rank'] = df['Team'].rank(method = 'first')
df
# Out:
#      Sl. No  Match No.       Team      Against Group  Goal  Possession (%)  \
# 0         1          1      Qatar      Ecuador     A     0              40
# 1         2          1    Ecuador        Qatar     A     2              46
# 2         3          2    England         Iran     B     6              69
# 3         4          2       Iran      England     B     2              20
# 4         5          3    Senegal  Netherlands     A     0              39
# ..      ...        ...        ...          ...   ...   ...             ...
# 123     124         62    Morocco         Fram     F     0              55
# 124     125         63    Croatia      Morocco     F     2              45
# 125     126         63    Morocco      Croatia     F     1              45
# 126     127         64  Argentina       France     C     3              46
# 127     128         64     France    Argentina     D     3              40
#
#      Inside Penalty Area  Outside Penalty Area  Assists  Total Attempts  \
# 0                      0                     0        0               5
# 1                      2                     0        1               5
# 2                      6                     0        6              13
# 3                      2                     0        1               8
# 4                      0                     0        0              15
# ..                   ...                   ...      ...             ...
# 123                    0                     0        0              13
# 124                    2                     0        2              14
# 125                    1                     0        0               7
# 126                    3                     0        1              21
# 127                    3                     0        1              10
#
#      On Target  Off Target  Target in Penalty  Target from Outside  \
# 0            0           5                  2                    3
# 1            5           2                  4                    1
# 2            7           3                 10                    3
# 3            3           4                  6                    2
# 4            4           7                  8                    7
# ..         ...         ...                ...                  ...
# 123          1           6                  8                    5
# 124          4           8                  7                    7
# 125          2           5                  5                    2
# 126          9           9                 13                    8
# 127          5           3                  7                    3
#
#      Left Channel  Left Inside Channel  Central Channel  Right Inside Channel  \
# 0              15                    0                3                     1
# 1               8                    7                6                     4
# 2              11                    5                2                     3
# 3               3                    0                3                     1
# 4              12                    4                2                     4
# ..            ...                  ...              ...                   ...
# 123            10                    4                6                     6
# 124            20                    8                3                     2
# 125            13                    1                3                     7
# 126            13                    6                8                     9
# 127            15                    7                5                     4
#
#      Right Channel  Receptions MD  Receptions D  Attempted Line Breaks  \
# 0                9             45             5                    159
# 1                6             55            10                    159
# 2               11             72            15                    133
# 3                1             34             1                     56
# 4               13            101            12                    143
# ..             ...            ...           ...                    ...
# 123             19             74            15                    141
# 124              7            106            15                    164
# 125             16             75            10                    150
# 126              9            163            28                    249
# 127             12             69             9                    179
#
#      Completed Line Breaks  Attempted Defensive Line Breaks  \
# 0                      100                                6
# 1                      103                                6
# 2                       94                                8
# 3                       19                                1
# 4                       86                                6
# ..                     ...                              ...
# 123                     95                               18
# 124                    114                               23
# 125                     97                               14
# 126                    172                               40
# 127                    107                               14
#
#      Completed Defensive Line Breaks  Yellow Cards  Red Cards  Fouls Against  \
# 0                                  4             4          0             15
# 1                                  4             2          0             15
# 2                                  6             0          0              9
# 3                                  1             2          0             14
# 4                                  6             2          0             13
# ..                               ...           ...        ...            ...
# 123                               11             1          0             11
# 124                               12             0          0             13
# 125                                8             2          0             11
# 126                               24             4          0             26
# 127                                9             3          0             19
#
#      Offsides  Passes  Passes Completed  Crosses  Crosses Completed  Corners  \
# 0           3     453               387       10                  5        1
# 1           4     484               419       26                 10        3
# 2           2     810               733       29                  9        8
# 3           2     232               156       11                  3        0
# 4           2     391               326       22                  8        6
# ..        ...     ...               ...      ...                ...      ...
# 123         3     583               518       22                  1        3
# 124         2     491               430       21                  3        6
# 125         2     494               428       20                  5        3
# 126         4     648               544       20                  4        6
# 127         4     516               419       24                  3        5
#
#      Free Kicks  Penalties Scored  Pts   rank
# 0            19                 0    0   95.0
# 1            17                 1    3   39.0
# 2            16                 0    3   42.0
# 3            10                 1    0   60.0
# 4            14                 0    0  101.0
# ..          ...               ...  ...    ...
# 123          15                 0    0   79.0
# 124          13                 0    3   35.0
# 125          15                 0    0   80.0
# 126          22                 5    3    7.0
# 127          28                 4    0   53.0
#
# [128 rows x 39 columns]

# %% [markdown]
# ### `Q-3:` Find out these below topics:
# - The information about the Fifa worldcup dataset.
# - The description about the Fifa worldcup dataset
# - Check is there any missing values, if there is any missing values, fill that value with the average value for that particular column.
# - Drop all the duplicate rows permanently.
# - Drop the columns: "Sl No", "Match No.", "Red Cards" and "Pts" permanently.

# %%
# code here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 39 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Sl. No                           128 non-null    int64
#  1   Match No.                        128 non-null    int64
#  2   Team                             128 non-null    object
#  3   Against                          128 non-null    object
#  4   Group                            128 non-null    object
#  5   Goal                             128 non-null    int64
#  6   Possession (%)                   128 non-null    int64
#  7   Inside Penalty Area              128 non-null    int64
#  8   Outside Penalty Area             128 non-null    int64
#  9   Assists                          128 non-null    int64
#  10  Total Attempts                   128 non-null    int64
#  11  On Target                        128 non-null    int64
#  12  Off Target                       128 non-null    int64
#  13  Target in Penalty                128 non-null    int64
#  14  Target from Outside              128 non-null    int64
#  15  Left Channel                     128 non-null    int64
#  16  Left Inside Channel              128 non-null    int64
#  17  Central Channel                  128 non-null    int64
#  18  Right Inside Channel             128 non-null    int64
#  19  Right Channel                    128 non-null    int64
#  20  Receptions MD                    128 non-null    int64
#  21  Receptions D                     128 non-null    int64
#  22  Attempted Line Breaks            128 non-null    int64
#  23  Completed Line Breaks            128 non-null    int64
#  24  Attempted Defensive Line Breaks  128 non-null    int64
#  25  Completed Defensive Line Breaks  128 non-null    int64
#  26  Yellow Cards                     128 non-null    int64
#  27  Red Cards                        128 non-null    int64
#  28  Fouls Against                    128 non-null    int64
#  29  Offsides                         128 non-null    int64
#  30  Passes                           128 non-null    int64
#  31  Passes Completed                 128 non-null    int64
#  32  Crosses                          128 non-null    int64
#  33  Crosses Completed                128 non-null    int64
#  34  Corners                          128 non-null    int64
#  35  Free Kicks                       128 non-null    int64
#  36  Penalties Scored                 128 non-null    int64
#  37  Pts                              128 non-null    int64
#  38  rank                             128 non-null    float64
# dtypes: float64(1), int64(35), object(3)
# memory usage: 39.1+ KB

# %%
df.describe()
# Out:
#            Sl. No   Match No.        Goal  Possession (%)  \
# count  128.000000  128.000000  128.000000      128.000000
# mean    64.500000   32.500000    1.343750       43.476562
# std     37.094474   18.545539    1.342448       11.442403
# min      1.000000    1.000000    0.000000       14.000000
# 25%     32.750000   16.750000    0.000000       35.000000
# 50%     64.500000   32.500000    1.000000       45.000000
# 75%     96.250000   48.250000    2.000000       51.000000
# max    128.000000   64.000000    7.000000       78.000000
#
#        Inside Penalty Area  Outside Penalty Area     Assists  Total Attempts  \
# count           128.000000            128.000000  128.000000      128.000000
# mean              1.203125              0.117188    0.914062       11.257812
# std               1.324270              0.322907    1.150333        5.406683
# min               0.000000              0.000000    0.000000        0.000000
# 25%               0.000000              0.000000    0.000000        7.750000
# 50%               1.000000              0.000000    1.000000       10.000000
# 75%               2.000000              0.000000    1.000000       14.000000
# max               7.000000              1.000000    6.000000       32.000000
#
#         On Target  Off Target  Target in Penalty  Target from Outside  \
# count  128.000000  128.000000         128.000000           128.000000
# mean     4.007812    4.835938           6.914062             4.343750
# std      2.588576    2.610630           3.998085             2.733397
# min      0.000000    0.000000           0.000000             0.000000
# 25%      2.000000    3.000000           4.000000             3.000000
# 50%      4.000000    4.000000           6.000000             4.000000
# 75%      6.000000    6.000000           9.000000             5.000000
# max     13.000000   17.000000          24.000000            15.000000
#
#        Left Channel  Left Inside Channel  Central Channel  \
# count    128.000000           128.000000       128.000000
# mean      13.562500             4.671875         4.906250
# std        6.901729             2.886595         3.080131
# min        2.000000             0.000000         0.000000
# 25%        8.000000             2.000000         3.000000
# 50%       12.000000             4.500000         4.000000
# 75%       18.000000             7.000000         6.250000
# max       36.000000            13.000000        16.000000
#
#        Right Inside Channel  Right Channel  Receptions MD  Receptions D  \
# count            128.000000     128.000000     128.000000    128.000000
# mean               4.648438      12.234375      92.703125     12.453125
# std                2.936573       6.176517      29.440547     18.152399
# min                0.000000       1.000000      32.000000      0.000000
# 25%                3.000000       8.000000      72.750000      7.000000
# 50%                4.000000      11.000000      93.000000      9.000000
# 75%                6.000000      16.250000     111.250000     14.000000
# max               19.000000      29.000000     186.000000    192.000000
#
#        Attempted Line Breaks  Completed Line Breaks  \
# count             128.000000             128.000000
# mean              169.281250             109.476562
# std                34.120661              30.776298
# min                56.000000              19.000000
# 25%               149.500000              87.750000
# 50%               170.500000             106.000000
# 75%               188.000000             129.000000
# max               259.000000             192.000000
#
#        Attempted Defensive Line Breaks  Completed Defensive Line Breaks  \
# count                       128.000000                       128.000000
# mean                         14.812500                         8.265625
# std                           7.230458                         5.101311
# min                           1.000000                         0.000000
# 25%                          10.000000                         5.000000
# 50%                          15.000000                         8.000000
# 75%                          20.000000                        11.000000
# max                          40.000000                        27.000000
#
#        Yellow Cards   Red Cards  Fouls Against    Offsides       Passes  \
# count    128.000000  128.000000     128.000000  128.000000   128.000000
# mean       1.726562    0.023438      12.320312    1.976562   502.859375
# std        1.514834    0.151883       4.691983    1.731891   160.160487
# min        0.000000    0.000000       0.000000    0.000000   225.000000
# 25%        1.000000    0.000000       9.000000    1.000000   398.250000
# 50%        2.000000    0.000000      12.000000    2.000000   495.500000
# 75%        2.000000    0.000000      15.000000    3.000000   589.500000
# max        8.000000    1.000000      30.000000   10.000000  1070.000000
#
#        Passes Completed     Crosses  Crosses Completed     Corners  \
# count        128.000000  128.000000         128.000000  128.000000
# mean         430.929688   19.523438           4.898438    4.468750
# std          160.893724    8.596799           3.520111    2.774852
# min          156.000000    4.000000           0.000000    0.000000
# 25%          323.250000   13.000000           3.000000    2.000000
# 50%          419.000000   19.000000           4.000000    4.000000
# 75%          519.750000   24.000000           6.000000    6.000000
# max          994.000000   53.000000          25.000000   14.000000
#
#        Free Kicks  Penalties Scored         Pts        rank
# count  128.000000        128.000000  128.000000  128.000000
# mean    14.250000          0.335938    1.429688   64.500000
# std      4.712189          0.941412    1.389973   37.094474
# min      5.000000          0.000000    0.000000    1.000000
# 25%     11.000000          0.000000    0.000000   32.750000
# 50%     14.000000          0.000000    1.000000   64.500000
# 75%     17.000000          0.000000    3.000000   96.250000
# max     30.000000          5.000000    3.000000  128.000000

# %%
df.isnull().sum()
# Out:
# Sl. No                             0
# Match No.                          0
# Team                               0
# Against                            0
# Group                              0
# Goal                               0
# Possession (%)                     0
# Inside Penalty Area                0
# Outside Penalty Area               0
# Assists                            0
# Total Attempts                     0
# On Target                          0
# Off Target                         0
# Target in Penalty                  0
# Target from Outside                0
# Left Channel                       0
# Left Inside Channel                0
# Central Channel                    0
# Right Inside Channel               0
# Right Channel                      0
# Receptions MD                      0
# Receptions D                       0
# Attempted Line Breaks              0
# Completed Line Breaks              0
# Attempted Defensive Line Breaks    0
# Completed Defensive Line Breaks    0
# Yellow Cards                       0
# Red Cards                          0
# Fouls Against                      0
# Offsides                           0
# Passes                             0
# Passes Completed                   0
# Crosses                            0
# Crosses Completed                  0
# Corners                            0
# Free Kicks                         0
# Penalties Scored                   0
# Pts                                0
# rank                               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(columns = ['Sl. No', 'Match No.', 'Red Cards', 'Pts'], inplace = True)

# %%
df.head()
# Out:
#       Team      Against Group  Goal  Possession (%)  Inside Penalty Area  \
# 0    Qatar      Ecuador     A     0              40                    0
# 1  Ecuador        Qatar     A     2              46                    2
# 2  England         Iran     B     6              69                    6
# 3     Iran      England     B     2              20                    2
# 4  Senegal  Netherlands     A     0              39                    0
#
#    Outside Penalty Area  Assists  Total Attempts  On Target  Off Target  \
# 0                     0        0               5          0           5
# 1                     0        1               5          5           2
# 2                     0        6              13          7           3
# 3                     0        1               8          3           4
# 4                     0        0              15          4           7
#
#    Target in Penalty  Target from Outside  Left Channel  Left Inside Channel  \
# 0                  2                    3            15                    0
# 1                  4                    1             8                    7
# 2                 10                    3            11                    5
# 3                  6                    2             3                    0
# 4                  8                    7            12                    4
#
#    Central Channel  Right Inside Channel  Right Channel  Receptions MD  \
# 0                3                     1              9             45
# 1                6                     4              6             55
# 2                2                     3             11             72
# 3                3                     1              1             34
# 4                2                     4             13            101
#
#    Receptions D  Attempted Line Breaks  Completed Line Breaks  \
# 0             5                    159                    100
# 1            10                    159                    103
# 2            15                    133                     94
# 3             1                     56                     19
# 4            12                    143                     86
#
#    Attempted Defensive Line Breaks  Completed Defensive Line Breaks  \
# 0                                6                                4
# 1                                6                                4
# 2                                8                                6
# 3                                1                                1
# 4                                6                                6
#
#    Yellow Cards  Fouls Against  Offsides  Passes  Passes Completed  Crosses  \
# 0             4             15         3     453               387       10
# 1             2             15         4     484               419       26
# 2             0              9         2     810               733       29
# 3             2             14         2     232               156       11
# 4             2             13         2     391               326       22
#
#    Crosses Completed  Corners  Free Kicks  Penalties Scored   rank
# 0                  5        1          19                 0   95.0
# 1                 10        3          17                 1   39.0
# 2                  9        8          16                 0   42.0
# 3                  3        0          10                 1   60.0
# 4                  8        6          14                 0  101.0

# %% [markdown]
# ###`Q-4:` Do these below operations:
# - Find out the rank based on the "Team" column and save the result by adding a new column named "Rank".
# - Change the datatype of this column to integer by using `np.int16`
# - Set the index of the DataFrame by using this "Rank" column permanently.
# - After that, sort the dataframe based on the "Rank" index.

# %%
df['rank'] = df['rank'].astype(np.int16)

# %%
df['rank']
# Out:
# 0       95
# 1       39
# 2       42
# 3       60
# 4      101
#       ...
# 123     79
# 124     35
# 125     80
# 126      7
# 127     53
# Name: rank, Length: 128, dtype: int16

# %%
# code here
df.set_index('rank', inplace = True)

# %%
df.sort_index()
# Out:
#            Team        Against Group  Goal  Possession (%)  \
# rank
# 1     Argentina   Saudi Arabia     C     1              51
# 2     Argentina         Mexico     C     2              50
# 3     Argentina         Poland     C     2              67
# 4     Argentina      Australia     C     2              53
# 5     Argentina    Netherlands     C     2              44
# ...         ...            ...   ...   ...             ...
# 124     Uruguay       Portugal     H     0              35
# 125     Uruguay          Ghana     H     2              39
# 126       Wales  United States     B     1              39
# 127       Wales           Iran     B     0              51
# 128       Wales        England     B     0              33
#
#       Inside Penalty Area  Outside Penalty Area  Assists  Total Attempts  \
# rank
# 1                       1                     0        0              14
# 2                       1                     1        2               5
# 3                       1                     1        2              25
# 4                       2                     0        1              14
# 5                       2                     0        1              15
# ...                   ...                   ...      ...             ...
# 124                     0                     0        0              10
# 125                     2                     0        1              12
# 126                     1                     0        0               7
# 127                     0                     0        0              10
# 128                     0                     0        0               7
#
#       On Target  Off Target  Target in Penalty  Target from Outside  \
# rank
# 1             6           6                 10                    4
# 2             2           3                  2                    3
# 3            13           8                 10                   15
# 4             5           7                 11                    3
# 5             6           8                  5                   10
# ...         ...         ...                ...                  ...
# 124           3           6                  6                    4
# 125           7           5                  7                    5
# 126           3           3                  5                    2
# 127           3           4                  5                    5
# 128           1           3                  1                    6
#
#       Left Channel  Left Inside Channel  Central Channel  \
# rank
# 1               12                    4                5
# 2               10                    6                2
# 3               25                    8                7
# 4               15                    6               11
# 5                7                    7               13
# ...            ...                  ...              ...
# 124             13                    8                4
# 125              7                    2               13
# 126              7                    2                5
# 127             18                    3                8
# 128              7                    1                2
#
#       Right Inside Channel  Right Channel  Receptions MD  Receptions D  \
# rank
# 1                        8             18             91            27
# 2                        4             12             89             2
# 3                       10             26            150            36
# 4                        2             17            127             8
# 5                        6             17            104             7
# ...                    ...            ...            ...           ...
# 124                      5              9             94             6
# 125                      3             17            186            14
# 126                      2              7             73             9
# 127                     11             13            101            13
# 128                      0              4             46             1
#
#       Attempted Line Breaks  Completed Line Breaks  \
# rank
# 1                       195                    127
# 2                       150                    100
# 3                       141                    126
# 4                       181                    135
# 5                       203                    122
# ...                     ...                    ...
# 124                     150                     86
# 125                     186                    124
# 126                     174                    103
# 127                     208                    129
# 128                     104                     55
#
#       Attempted Defensive Line Breaks  Completed Defensive Line Breaks  \
# rank
# 1                                  10                                8
# 2                                  10                                5
# 3                                  20                               16
# 4                                  16                                8
# 5                                  24                                8
# ...                               ...                              ...
# 124                                17                               11
# 125                                24                               14
# 126                                17                                8
# 127                                17                                8
# 128                                 4                                1
#
#       Yellow Cards  Fouls Against  Offsides  Passes  Passes Completed  \
# rank
# 1                0              7        10     593               525
# 2                1             15         2     533               464
# 3                1             11         0     862               814
# 4                0              8         4     711               635
# 5                8             18         2     603               511
# ...            ...            ...       ...     ...               ...
# 124              2             16         0     390               306
# 125              3             11         2     446               361
# 126              2             10         1     409               321
# 127              1              9         2     508               413
# 128              2             16         1     325               261
#
#       Crosses  Crosses Completed  Corners  Free Kicks  Penalties Scored
# rank
# 1          36                 15        9          21                 1
# 2          14                  2        4          23                 0
# 3          22                  5        9           5                 0
# 4           6                  1        1          15                 0
# 5          16                  4        8          30                 5
# ...       ...                ...      ...         ...               ...
# 124        18                  5        2          13                 0
# 125        15                  4        2          20                 0
# 126        15                  6        3          15                 1
# 127        20                  5        2          12                 0
# 128         4                  1        1          10                 0
#
# [128 rows x 34 columns]

# %% [markdown]
# ## Questions on Titanic dataset.
#
# You can get the dataset from [here](https://www.kaggle.com/competitions/titanic). This is the competition page on Kaggle. To download the dataset from here, I guess you have to register for the compition. So, do so and then download the dataset.
#
# Also, for now you can use this url to read the dataset like before:
# - dataset 1: https://docs.google.com/spreadsheets/d/e/2PACX-1vQjh5HzZ1N0SU7ME9ZQRzeVTaXaGsV97rU8R7eAcg53k27GTstJp9cRUOfr55go1GRRvTz1NwvyOnuh/pub?gid=1562145139&single=true&output=csv
# - dataset 2: https://docs.google.com/spreadsheets/d/e/2PACX-1vQcPvQsSC9aNFogvbUG08nu0bGHlOclGYaOlhND_LE5Ff7ZnHQ5VYzAgpyT5XNklgiT54SsNgHePsUa/pub?gid=1656109608&single=true&output=csv

# %% [markdown]
# ### `Q-5:` Do the below tasks:
# 1. With dataset 1, drop those records which only have missing values of the "Age" column permanently.
#
# 2. With the dataset 2, fill the missing values with 20 to the only "Age" column permanently.

# %%
# code here
df1 = pd.read_csv(' https://docs.google.com/spreadsheets/d/e/2PACX-1vQjh5HzZ1N0SU7ME9ZQRzeVTaXaGsV97rU8R7eAcg53k27GTstJp9cRUOfr55go1GRRvTz1NwvyOnuh/pub?gid=1562145139&single=true&output=csv')
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df1.dropna(subset= 'Age', inplace = True)
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df2 = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vQcPvQsSC9aNFogvbUG08nu0bGHlOclGYaOlhND_LE5Ff7ZnHQ5VYzAgpyT5XNklgiT54SsNgHePsUa/pub?gid=1656109608&single=true&output=csv')
df2.head(2)
# Out:
#    PassengerId  Pclass                              Name     Sex   Age  SibSp  \
# 0          892       3                  Kelly, Mr. James    male  34.5      0
# 1          893       3  Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
#
#    Parch  Ticket    Fare Cabin Embarked
# 0      0  330911  7.8292   NaN        Q
# 1      0  363272  7.0000   NaN        S

# %%
df2['Age'] = df2['Age'].fillna(20)

# %% [markdown]
# ## Questions on IPL wala dataset
#
# matches dataset = https://drive.google.com/file/d/1yKVUuexl6lIKuFQy7uIPgDgXhJ0L4SIg/view?usp=share_link
#
# Code to directly use in colab
# ```
# ipl_matches = "https://docs.google.com/spreadsheets/d/e/2PACX-1vRy2DUdUbaKx_Co9F0FSnIlyS-8kp4aKv_I0-qzNeghiZHAI_hw94gKG22XTxNJHMFnFVKsO4xWOdIs/pub?gid=1655759976&single=true&output=csv"
#
# ```

# %% [markdown]
# ###`Q-6:` Make a dataframe of each team in IPL with details like - Team Name, Matches Played, Win%, Home Win%, Away Win%.
# Show sorted dataframe on Win%
#
# Replace old team name as new name before performing any tasks.
# ```
# Delhi Daredevils ->Delhi Capitals
# Kings XI Punjab -> Punjab Kings
# Rising Pune Supergiants -> Rising Pune Supergiant
# ```
#
# Note: Team1 represents Home team. Exclude not result matches.

# %%
# code here
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vRy2DUdUbaKx_Co9F0FSnIlyS-8kp4aKv_I0-qzNeghiZHAI_hw94gKG22XTxNJHMFnFVKsO4xWOdIs/pub?gid=1655759976&single=true&output=csv')
df.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3             Eden Gardens, Kolkata        Gujarat Titans        field
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# 2         N  Royal Challengers Bangalore     Runs    14.0    NaN
# 3         N               Gujarat Titans  Wickets     7.0    NaN
# 4         N                 Punjab Kings  Wickets     5.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2
# 0    Nitin Menon
# 1    Nitin Menon
# 2       MA Gough
# 3      VK Sharma
# 4  NA Patwardhan

# %%
df['Team1'] = df['Team1'].str.replace('Delhi Daredevils', 'Delhi Capitals')
df['Team2'] = df['Team2'].str.replace('Delhi Daredevils', 'Delhi Capitals')
df['WinningTeam'] = df['WinningTeam'].str.replace('Delhi Daredevils', 'Delhi Capitals')
df['Team1'].value_counts()
# Out:
# Team1
# Royal Challengers Bangalore    126
# Delhi Capitals                 114
# Mumbai Indians                 112
# Chennai Super Kings            111
# Kolkata Knight Riders          105
# Kings XI Punjab                 92
# Rajasthan Royals                89
# Sunrisers Hyderabad             69
# Deccan Chargers                 39
# Pune Warriors                   23
# Punjab Kings                    18
# Gujarat Lions                   16
# Lucknow Super Giants             8
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Gujarat Titans                   7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %%
df['Team1'] = df['Team1'].str.replace('Kings XI Punjab', 'Punjab Kings')
df['Team2'] = df['Team2'].str.replace('Kings XI Punjab', 'Punjab Kings')
df['WinningTeam'] = df['WinningTeam'].str.replace('Kings XI Punjab', 'Punjab Kings')

df['Team1'] = df['Team1'].str.replace('Rising Pune Supergiants', 'Rising Pune Supergiant')
df['Team2'] = df['Team2'].str.replace('Rising Pune Supergiants', 'Rising Pune Supergiant')
df['WinningTeam'] = df['WinningTeam'].str.replace('Rising Pune Supergiants', 'Rising Pune Supergiant')
df['Team1'].value_counts()
# Out:
# Team1
# Royal Challengers Bangalore    126
# Delhi Capitals                 114
# Mumbai Indians                 112
# Chennai Super Kings            111
# Punjab Kings                   110
# Kolkata Knight Riders          105
# Rajasthan Royals                89
# Sunrisers Hyderabad             69
# Deccan Chargers                 39
# Pune Warriors                   23
# Gujarat Lions                   16
# Rising Pune Supergiant          14
# Lucknow Super Giants             8
# Gujarat Titans                   7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %%
df1 = df.dropna(subset = ['WinningTeam'])
df1.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3             Eden Gardens, Kolkata        Gujarat Titans        field
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# 2         N  Royal Challengers Bangalore     Runs    14.0    NaN
# 3         N               Gujarat Titans  Wickets     7.0    NaN
# 4         N                 Punjab Kings  Wickets     5.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2
# 0    Nitin Menon
# 1    Nitin Menon
# 2       MA Gough
# 3      VK Sharma
# 4  NA Patwardhan

# %%
ipl = pd.DataFrame()
ipl['Total_matches'] = df1['Team1'].value_counts() + df['Team2'].value_counts()
ipl
# Out:
#                              Total_matches
# Chennai Super Kings                    208
# Deccan Chargers                         75
# Delhi Capitals                         223
# Gujarat Lions                           30
# Gujarat Titans                          16
# Kochi Tuskers Kerala                    14
# Kolkata Knight Riders                  223
# Lucknow Super Giants                    15
# Mumbai Indians                         231
# Pune Warriors                           46
# Punjab Kings                           218
# Rajasthan Royals                       192
# Rising Pune Supergiant                  30
# Royal Challengers Bangalore            223
# Sunrisers Hyderabad                    152

# %%
ipl['wins'] = df1.groupby(['WinningTeam'])['ID'].count()
ipl
# Out:
#                              Total_matches  wins
# Chennai Super Kings                    208   121
# Deccan Chargers                         75    29
# Delhi Capitals                         223   103
# Gujarat Lions                           30    13
# Gujarat Titans                          16    12
# Kochi Tuskers Kerala                    14     6
# Kolkata Knight Riders                  223   114
# Lucknow Super Giants                    15     9
# Mumbai Indians                         231   131
# Pune Warriors                           46    12
# Punjab Kings                           218   101
# Rajasthan Royals                       192    96
# Rising Pune Supergiant                  30    15
# Royal Challengers Bangalore            223   109
# Sunrisers Hyderabad                    152    75

# %%
ipl['home_matches'] = df1['Team1'].value_counts()
ipl
# Out:
#                              Total_matches  wins  home_matches
# Chennai Super Kings                    208   121           111
# Deccan Chargers                         75    29            39
# Delhi Capitals                         223   103           113
# Gujarat Lions                           30    13            16
# Gujarat Titans                          16    12             7
# Kochi Tuskers Kerala                    14     6             7
# Kolkata Knight Riders                  223   114           105
# Lucknow Super Giants                    15     9             8
# Mumbai Indians                         231   131           112
# Pune Warriors                           46    12            23
# Punjab Kings                           218   101           110
# Rajasthan Royals                       192    96            89
# Rising Pune Supergiant                  30    15            14
# Royal Challengers Bangalore            223   109           123
# Sunrisers Hyderabad                    152    75            69

# %%
ipl['home_wins'] = df[df['Team1'] == df['WinningTeam']]['Team1'].value_counts()
ipl
# Out:
#                              Total_matches  wins  home_matches  home_wins
# Chennai Super Kings                    208   121           111         65
# Deccan Chargers                         75    29            39         13
# Delhi Capitals                         223   103           113         53
# Gujarat Lions                           30    13            16          5
# Gujarat Titans                          16    12             7          4
# Kochi Tuskers Kerala                    14     6             7          3
# Kolkata Knight Riders                  223   114           105         56
# Lucknow Super Giants                    15     9             8          7
# Mumbai Indians                         231   131           112         65
# Pune Warriors                           46    12            23          6
# Punjab Kings                           218   101           110         50
# Rajasthan Royals                       192    96            89         49
# Rising Pune Supergiant                  30    15            14          7
# Royal Challengers Bangalore            223   109           123         61
# Sunrisers Hyderabad                    152    75            69         36

# %%
ipl['away_matches'] = ipl['Total_matches'] - ipl['home_matches']
ipl['away_wins'] = ipl['wins'] - ipl['home_wins']
ipl
# Out:
#                              Total_matches  wins  home_matches  home_wins  \
# Chennai Super Kings                    208   121           111         65
# Deccan Chargers                         75    29            39         13
# Delhi Capitals                         223   103           113         53
# Gujarat Lions                           30    13            16          5
# Gujarat Titans                          16    12             7          4
# Kochi Tuskers Kerala                    14     6             7          3
# Kolkata Knight Riders                  223   114           105         56
# Lucknow Super Giants                    15     9             8          7
# Mumbai Indians                         231   131           112         65
# Pune Warriors                           46    12            23          6
# Punjab Kings                           218   101           110         50
# Rajasthan Royals                       192    96            89         49
# Rising Pune Supergiant                  30    15            14          7
# Royal Challengers Bangalore            223   109           123         61
# Sunrisers Hyderabad                    152    75            69         36
#
#                              away_matches  away_wins
# Chennai Super Kings                    97         56
# Deccan Chargers                        36         16
# Delhi Capitals                        110         50
# Gujarat Lions                          14          8
# Gujarat Titans                          9          8
# Kochi Tuskers Kerala                    7          3
# Kolkata Knight Riders                 118         58
# Lucknow Super Giants                    7          2
# Mumbai Indians                        119         66
# Pune Warriors                          23          6
# Punjab Kings                          108         51
# Rajasthan Royals                      103         47
# Rising Pune Supergiant                 16          8
# Royal Challengers Bangalore           100         48
# Sunrisers Hyderabad                    83         39

# %%
ipl['win%'] = (ipl['wins'] / ipl['Total_matches']) * 100
ipl['home_wins%'] = (ipl['home_wins'] / ipl['home_matches']) * 100
ipl['away_wins%'] = (ipl['away_wins'] / ipl['away_matches']) * 100
ipl
# Out:
#                              Total_matches  wins  home_matches  home_wins  \
# Chennai Super Kings                    208   121           111         65
# Deccan Chargers                         75    29            39         13
# Delhi Capitals                         223   103           113         53
# Gujarat Lions                           30    13            16          5
# Gujarat Titans                          16    12             7          4
# Kochi Tuskers Kerala                    14     6             7          3
# Kolkata Knight Riders                  223   114           105         56
# Lucknow Super Giants                    15     9             8          7
# Mumbai Indians                         231   131           112         65
# Pune Warriors                           46    12            23          6
# Punjab Kings                           218   101           110         50
# Rajasthan Royals                       192    96            89         49
# Rising Pune Supergiant                  30    15            14          7
# Royal Challengers Bangalore            223   109           123         61
# Sunrisers Hyderabad                    152    75            69         36
#
#                              away_matches  away_wins       win%  home_wins%  \
# Chennai Super Kings                    97         56  58.173077   58.558559
# Deccan Chargers                        36         16  38.666667   33.333333
# Delhi Capitals                        110         50  46.188341   46.902655
# Gujarat Lions                          14          8  43.333333   31.250000
# Gujarat Titans                          9          8  75.000000   57.142857
# Kochi Tuskers Kerala                    7          3  42.857143   42.857143
# Kolkata Knight Riders                 118         58  51.121076   53.333333
# Lucknow Super Giants                    7          2  60.000000   87.500000
# Mumbai Indians                        119         66  56.709957   58.035714
# Pune Warriors                          23          6  26.086957   26.086957
# Punjab Kings                          108         51  46.330275   45.454545
# Rajasthan Royals                      103         47  50.000000   55.056180
# Rising Pune Supergiant                 16          8  50.000000   50.000000
# Royal Challengers Bangalore           100         48  48.878924   49.593496
# Sunrisers Hyderabad                    83         39  49.342105   52.173913
#
#                              away_wins%
# Chennai Super Kings           57.731959
# Deccan Chargers               44.444444
# Delhi Capitals                45.454545
# Gujarat Lions                 57.142857
# Gujarat Titans                88.888889
# Kochi Tuskers Kerala          42.857143
# Kolkata Knight Riders         49.152542
# Lucknow Super Giants          28.571429
# Mumbai Indians                55.462185
# Pune Warriors                 26.086957
# Punjab Kings                  47.222222
# Rajasthan Royals              45.631068
# Rising Pune Supergiant        50.000000
# Royal Challengers Bangalore   48.000000
# Sunrisers Hyderabad           46.987952

# %%
ipl.sort_values(by = 'win%', ascending = False)
# Out:
#                              Total_matches  wins  home_matches  home_wins  \
# Gujarat Titans                          16    12             7          4
# Lucknow Super Giants                    15     9             8          7
# Chennai Super Kings                    208   121           111         65
# Mumbai Indians                         231   131           112         65
# Kolkata Knight Riders                  223   114           105         56
# Rajasthan Royals                       192    96            89         49
# Rising Pune Supergiant                  30    15            14          7
# Sunrisers Hyderabad                    152    75            69         36
# Royal Challengers Bangalore            223   109           123         61
# Punjab Kings                           218   101           110         50
# Delhi Capitals                         223   103           113         53
# Gujarat Lions                           30    13            16          5
# Kochi Tuskers Kerala                    14     6             7          3
# Deccan Chargers                         75    29            39         13
# Pune Warriors                           46    12            23          6
#
#                              away_matches  away_wins       win%  home_wins%  \
# Gujarat Titans                          9          8  75.000000   57.142857
# Lucknow Super Giants                    7          2  60.000000   87.500000
# Chennai Super Kings                    97         56  58.173077   58.558559
# Mumbai Indians                        119         66  56.709957   58.035714
# Kolkata Knight Riders                 118         58  51.121076   53.333333
# Rajasthan Royals                      103         47  50.000000   55.056180
# Rising Pune Supergiant                 16          8  50.000000   50.000000
# Sunrisers Hyderabad                    83         39  49.342105   52.173913
# Royal Challengers Bangalore           100         48  48.878924   49.593496
# Punjab Kings                          108         51  46.330275   45.454545
# Delhi Capitals                        110         50  46.188341   46.902655
# Gujarat Lions                          14          8  43.333333   31.250000
# Kochi Tuskers Kerala                    7          3  42.857143   42.857143
# Deccan Chargers                        36         16  38.666667   33.333333
# Pune Warriors                          23          6  26.086957   26.086957
#
#                              away_wins%
# Gujarat Titans                88.888889
# Lucknow Super Giants          28.571429
# Chennai Super Kings           57.731959
# Mumbai Indians                55.462185
# Kolkata Knight Riders         49.152542
# Rajasthan Royals              45.631068
# Rising Pune Supergiant        50.000000
# Sunrisers Hyderabad           46.987952
# Royal Challengers Bangalore   48.000000
# Punjab Kings                  47.222222
# Delhi Capitals                45.454545
# Gujarat Lions                 57.142857
# Kochi Tuskers Kerala          42.857143
# Deccan Chargers               44.444444
# Pune Warriors                 26.086957

# %% [markdown]
# ###`Q-7:` Venues with most "no result" matches.

# %%
# code here
df[df['WinningTeam'].isna()]['Venue'].value_counts().sort_values(ascending = False).head(1)
# Out:
# Venue
# M Chinnaswamy Stadium    2
# Name: count, dtype: int64

# %% [markdown]
# ###`Q-8:` Player with most appearance in final match.
#
# `Team1Players` and `Team2Players` have all players name. It is not a list of players name instead it is str. So handle it as string.
#
# Hint: split and strip will help; Make a series of all players in final and do value counts

# %%
temp = df[df['MatchNumber'] == 'Final']
temp
# Out:
#           ID          City        Date   Season MatchNumber  \
# 0    1312200     Ahmedabad  2022-05-29     2022       Final
# 74   1254117         Dubai  2021-10-15     2021       Final
# 134  1237181           NaN  2020-11-10  2020/21       Final
# 194  1181768     Hyderabad  2019-05-12     2019       Final
# 254  1136620        Mumbai  2018-05-27     2018       Final
# 314  1082650     Hyderabad  2017-05-21     2017       Final
# 373   981019     Bangalore  2016-05-29     2016       Final
# 433   829823       Kolkata  2015-05-24     2015       Final
# 492   734049     Bangalore  2014-06-01     2014       Final
# 552   598073       Kolkata  2013-05-26     2013       Final
# 628   548381       Chennai  2012-05-27     2012       Final
# 702   501271       Chennai  2011-05-28     2011       Final
# 775   419165        Mumbai  2010-04-25  2009/10       Final
# 835   392239  Johannesburg  2009-05-24     2009       Final
# 892   336040        Mumbai  2008-06-01  2007/08       Final
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 74           Chennai Super Kings        Kolkata Knight Riders
# 134               Delhi Capitals               Mumbai Indians
# 194               Mumbai Indians          Chennai Super Kings
# 254          Sunrisers Hyderabad          Chennai Super Kings
# 314               Mumbai Indians       Rising Pune Supergiant
# 373  Royal Challengers Bangalore          Sunrisers Hyderabad
# 433               Mumbai Indians          Chennai Super Kings
# 492        Kolkata Knight Riders                 Punjab Kings
# 552          Chennai Super Kings               Mumbai Indians
# 628        Kolkata Knight Riders          Chennai Super Kings
# 702          Chennai Super Kings  Royal Challengers Bangalore
# 775          Chennai Super Kings               Mumbai Indians
# 835  Royal Challengers Bangalore              Deccan Chargers
# 892          Chennai Super Kings             Rajasthan Royals
#
#                                          Venue                   TossWinner  \
# 0             Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 74         Dubai International Cricket Stadium        Kolkata Knight Riders
# 134        Dubai International Cricket Stadium               Delhi Capitals
# 194         Rajiv Gandhi International Stadium               Mumbai Indians
# 254                           Wankhede Stadium          Chennai Super Kings
# 314  Rajiv Gandhi International Stadium, Uppal               Mumbai Indians
# 373                      M Chinnaswamy Stadium          Sunrisers Hyderabad
# 433                               Eden Gardens          Chennai Super Kings
# 492                      M Chinnaswamy Stadium        Kolkata Knight Riders
# 552                               Eden Gardens               Mumbai Indians
# 628            MA Chidambaram Stadium, Chepauk          Chennai Super Kings
# 702            MA Chidambaram Stadium, Chepauk          Chennai Super Kings
# 775                 Dr DY Patil Sports Academy          Chennai Super Kings
# 835                      New Wanderers Stadium  Royal Challengers Bangalore
# 892                 Dr DY Patil Sports Academy             Rajasthan Royals
#
#     TossDecision SuperOver            WinningTeam    WonBy  Margin method  \
# 0            bat         N         Gujarat Titans  Wickets     7.0    NaN
# 74         field         N    Chennai Super Kings     Runs    27.0    NaN
# 134          bat         N         Mumbai Indians  Wickets     5.0    NaN
# 194          bat         N         Mumbai Indians     Runs     1.0    NaN
# 254        field         N    Chennai Super Kings  Wickets     8.0    NaN
# 314          bat         N         Mumbai Indians     Runs     1.0    NaN
# 373          bat         N    Sunrisers Hyderabad     Runs     8.0    NaN
# 433        field         N         Mumbai Indians     Runs    41.0    NaN
# 492        field         N  Kolkata Knight Riders  Wickets     3.0    NaN
# 552          bat         N         Mumbai Indians     Runs    23.0    NaN
# 628          bat         N  Kolkata Knight Riders  Wickets     5.0    NaN
# 702          bat         N    Chennai Super Kings     Runs    58.0    NaN
# 775          bat         N    Chennai Super Kings     Runs    22.0    NaN
# 835        field         N        Deccan Chargers     Runs     6.0    NaN
# 892        field         N       Rajasthan Royals  Wickets     3.0    NaN
#
#     Player_of_Match                                       Team1Players  \
# 0         HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 74     F du Plessis  ['RD Gaikwad', 'F du Plessis', 'RV Uthappa', '...
# 134        TA Boult  ['MP Stoinis', 'S Dhawan', 'AM Rahane', 'SS Iy...
# 194       JJ Bumrah  ['Q de Kock', 'RG Sharma', 'SA Yadav', 'Ishan ...
# 254       SR Watson  ['SP Goswami', 'S Dhawan', 'KS Williamson', 'S...
# 314       KH Pandya  ['LMP Simmons', 'PA Patel', 'AT Rayudu', 'RG S...
# 373     BCJ Cutting  ['CH Gayle', 'V Kohli', 'AB de Villiers', 'KL ...
# 433       RG Sharma  ['LMP Simmons', 'PA Patel', 'RG Sharma', 'KA P...
# 492       MK Pandey  ['RV Uthappa', 'G Gambhir', 'MK Pandey', 'YK P...
# 552      KA Pollard  ['MEK Hussey', 'M Vijay', 'SK Raina', 'S Badri...
# 628        MS Bisla  ['MS Bisla', 'G Gambhir', 'JH Kallis', 'LR Shu...
# 702         M Vijay  ['MEK Hussey', 'M Vijay', 'MS Dhoni', 'SK Rain...
# 775        SK Raina  ['M Vijay', 'ML Hayden', 'SK Raina', 'S Badrin...
# 835        A Kumble  ['JH Kallis', 'MK Pandey', 'RE van der Merwe',...
# 892       YK Pathan  ['PA Patel', 'S Vidyut', 'SK Raina', 'JA Morke...
#
#                                           Team2Players          Umpire1  \
# 0    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...      CB Gaffaney
# 74   ['Shubman Gill', 'VR Iyer', 'N Rana', 'SP Nari...      Nitin Menon
# 134  ['RG Sharma', 'Q de Kock', 'SA Yadav', 'Ishan ...      CB Gaffaney
# 194  ['F du Plessis', 'SR Watson', 'SK Raina', 'AT ...         IJ Gould
# 254  ['SR Watson', 'F du Plessis', 'SK Raina', 'AT ...        M Erasmus
# 314  ['AM Rahane', 'RA Tripathi', 'SPD Smith', 'MS ...         NJ Llong
# 373  ['DA Warner', 'S Dhawan', 'MC Henriques', 'Yuv...  HDPK Dharmasena
# 433  ['DR Smith', 'MEK Hussey', 'SK Raina', 'MS Dho...  HDPK Dharmasena
# 492  ['V Sehwag', 'M Vohra', 'GJ Bailey', 'WP Saha'...  HDPK Dharmasena
# 552  ['DR Smith', 'AP Tare', 'KD Karthik', 'RG Shar...  HDPK Dharmasena
# 628  ['MEK Hussey', 'M Vijay', 'SK Raina', 'MS Dhon...        BF Bowden
# 702  ['MA Agarwal', 'CH Gayle', 'V Kohli', 'AB de V...        Asad Rauf
# 775  ['S Dhawan', 'SR Tendulkar', 'AM Nayar', 'Harb...      RE Koertzen
# 835  ['AC Gilchrist', 'HH Gibbs', 'TL Suman', 'A Sy...      RE Koertzen
# 892  ['NK Patel', 'SA Asnodkar', 'Kamran Akmal', 'S...        BF Bowden
#
#             Umpire2
# 0       Nitin Menon
# 74   RK Illingworth
# 134     Nitin Menon
# 194     Nitin Menon
# 254          S Ravi
# 314          S Ravi
# 373    BNJ Oxenford
# 433  RK Illingworth
# 492    BNJ Oxenford
# 552      SJA Taufel
# 628      SJA Taufel
# 702      SJA Taufel
# 775      SJA Taufel
# 835      SJA Taufel
# 892     RE Koertzen

# %%
# code here
players = pd.concat([temp['Team1Players'] ,temp['Team2Players']])
players
# Out:
# 0      ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 74     ['RD Gaikwad', 'F du Plessis', 'RV Uthappa', '...
# 134    ['MP Stoinis', 'S Dhawan', 'AM Rahane', 'SS Iy...
# 194    ['Q de Kock', 'RG Sharma', 'SA Yadav', 'Ishan ...
# 254    ['SP Goswami', 'S Dhawan', 'KS Williamson', 'S...
# 314    ['LMP Simmons', 'PA Patel', 'AT Rayudu', 'RG S...
# 373    ['CH Gayle', 'V Kohli', 'AB de Villiers', 'KL ...
# 433    ['LMP Simmons', 'PA Patel', 'RG Sharma', 'KA P...
# 492    ['RV Uthappa', 'G Gambhir', 'MK Pandey', 'YK P...
# 552    ['MEK Hussey', 'M Vijay', 'SK Raina', 'S Badri...
# 628    ['MS Bisla', 'G Gambhir', 'JH Kallis', 'LR Shu...
# 702    ['MEK Hussey', 'M Vijay', 'MS Dhoni', 'SK Rain...
# 775    ['M Vijay', 'ML Hayden', 'SK Raina', 'S Badrin...
# 835    ['JH Kallis', 'MK Pandey', 'RE van der Merwe',...
# 892    ['PA Patel', 'S Vidyut', 'SK Raina', 'JA Morke...
# 0      ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...
# 74     ['Shubman Gill', 'VR Iyer', 'N Rana', 'SP Nari...
# 134    ['RG Sharma', 'Q de Kock', 'SA Yadav', 'Ishan ...
# 194    ['F du Plessis', 'SR Watson', 'SK Raina', 'AT ...
# 254    ['SR Watson', 'F du Plessis', 'SK Raina', 'AT ...
# 314    ['AM Rahane', 'RA Tripathi', 'SPD Smith', 'MS ...
# 373    ['DA Warner', 'S Dhawan', 'MC Henriques', 'Yuv...
# 433    ['DR Smith', 'MEK Hussey', 'SK Raina', 'MS Dho...
# 492    ['V Sehwag', 'M Vohra', 'GJ Bailey', 'WP Saha'...
# 552    ['DR Smith', 'AP Tare', 'KD Karthik', 'RG Shar...
# 628    ['MEK Hussey', 'M Vijay', 'SK Raina', 'MS Dhon...
# 702    ['MA Agarwal', 'CH Gayle', 'V Kohli', 'AB de V...
# 775    ['S Dhawan', 'SR Tendulkar', 'AM Nayar', 'Harb...
# 835    ['AC Gilchrist', 'HH Gibbs', 'TL Suman', 'A Sy...
# 892    ['NK Patel', 'SA Asnodkar', 'Kamran Akmal', 'S...
# dtype: object

# %%
players.str.split(',').explode().str.strip('[').str.strip(']').value_counts().idxmax()
# Out:
# " 'MS Dhoni'"

# %%
players_dict = {}
for i in range(temp['Players'].shape[0]):
    for player in temp['Players'].values[i]:
        if player in players_dict:
            players_dict[player] += 1
        else:
            players_dict[player] = 1
most = dict(sorted(players_dict.items(), key = lambda x: x[1], reverse = True))
most
# Out:
# {" 'MS Dhoni'": 10,
#  " 'SK Raina'": 8,
#  " 'R Ashwin'": 7,
#  " 'AT Rayudu'": 7,
#  " 'RA Jadeja'": 7,
#  " 'DJ Bravo'": 7,
#  " 'KA Pollard'": 6,
#  " 'HH Pandya'": 5,
#  " 'RG Sharma'": 5,
#  " 'SL Malinga'": 5,
#  " 'S Badrinath'": 5,
#  " 'JA Morkel'": 5,
#  " 'SN Thakur'": 4,
#  " 'Shakib Al Hasan'": 4,
#  " 'Harbhajan Singh'": 4,
#  " 'YK Pathan'": 4,
#  " 'LH Ferguson'": 3,
#  " 'F du Plessis'": 3,
#  " 'DL Chahar'": 3,
#  " 'SP Narine'": 3,
#  " 'S Dhawan'": 3,
#  " 'SA Yadav'": 3,
#  " 'KH Pandya'": 3,
#  " 'JJ Bumrah'": 3,
#  " 'SR Watson'": 3,
#  " 'MG Johnson'": 3,
#  " 'V Kohli'": 3,
#  "'MEK Hussey'": 3,
#  " 'M Vijay'": 3,
#  " 'SB Jakati'": 3,
#  " 'SO Hetmyer'": 2,
#  " 'TA Boult'": 2,
#  " 'YS Chahal'": 2,
#  " 'DA Miller'": 2,
#  " 'Rashid Khan'": 2,
#  " 'RV Uthappa'": 2,
#  " 'KD Karthik'": 2,
#  " 'RA Tripathi'": 2,
#  " 'AR Patel'": 2,
#  " 'Ishan Kishan'": 2,
#  " 'MJ McClenaghan'": 2,
#  " 'DJ Hooda'": 2,
#  " 'B Kumar'": 2,
#  " 'KV Sharma'": 2,
#  "'LMP Simmons'": 2,
#  " 'PA Patel'": 2,
#  " 'MK Tiwary'": 2,
#  " 'AB de Villiers'": 2,
#  " 'Iqbal Abdulla'": 2,
#  " 'S Aravind'": 2,
#  " 'R Vinay Kumar'": 2,
#  "'DR Smith'": 2,
#  " 'MM Sharma'": 2,
#  " 'G Gambhir'": 2,
#  " 'MK Pandey'": 2,
#  " 'WP Saha'": 2,
#  " 'L Balaji'": 2,
#  " 'PP Ojha'": 2,
#  " 'DE Bollinger'": 2,
#  " 'SS Tiwary'": 2,
#  " 'Z Khan'": 2,
#  " 'M Muralitharan'": 2,
#  "'YBK Jaiswal'": 1,
#  " 'JC Buttler'": 1,
#  " 'SV Samson'": 1,
#  " 'D Padikkal'": 1,
#  " 'R Parag'": 1,
#  " 'OC McCoy'": 1,
#  " 'M Prasidh Krishna'": 1,
#  "'WP Saha'": 1,
#  " 'Shubman Gill'": 1,
#  " 'MS Wade'": 1,
#  " 'R Tewatia'": 1,
#  " 'R Sai Kishore'": 1,
#  " 'Yash Dayal'": 1,
#  " 'Mohammed Shami'": 1,
#  "'RD Gaikwad'": 1,
#  " 'MM Ali'": 1,
#  " 'JR Hazlewood'": 1,
#  "'Shubman Gill'": 1,
#  " 'VR Iyer'": 1,
#  " 'N Rana'": 1,
#  " 'EJG Morgan'": 1,
#  " 'Shivam Mavi'": 1,
#  " 'CV Varun'": 1,
#  "'MP Stoinis'": 1,
#  " 'AM Rahane'": 1,
#  " 'SS Iyer'": 1,
#  " 'RR Pant'": 1,
#  " 'K Rabada'": 1,
#  " 'P Dubey'": 1,
#  " 'A Nortje'": 1,
#  "'RG Sharma'": 1,
#  " 'Q de Kock'": 1,
#  " 'J Yadav'": 1,
#  " 'NM Coulter-Nile'": 1,
#  "'Q de Kock'": 1,
#  " 'RD Chahar'": 1,
#  "'F du Plessis'": 1,
#  " 'Imran Tahir'": 1,
#  "'SP Goswami'": 1,
#  " 'KS Williamson'": 1,
#  " 'CR Brathwaite'": 1,
#  " 'S Kaul'": 1,
#  " 'Sandeep Sharma'": 1,
#  "'SR Watson'": 1,
#  " 'L Ngidi'": 1,
#  "'AM Rahane'": 1,
#  " 'SPD Smith'": 1,
#  " 'DT Christian'": 1,
#  " 'Washington Sundar'": 1,
#  " 'A Zampa'": 1,
#  " 'JD Unadkat'": 1,
#  "'CH Gayle'": 1,
#  " 'KL Rahul'": 1,
#  " 'Sachin Baby'": 1,
#  " 'STR Binny'": 1,
#  " 'CJ Jordan'": 1,
#  "'DA Warner'": 1,
#  " 'MC Henriques'": 1,
#  " 'Yuvraj Singh'": 1,
#  " 'BCJ Cutting'": 1,
#  " 'NV Ojha'": 1,
#  " 'Bipul Sharma'": 1,
#  " 'BB Sran'": 1,
#  " 'Mustafizur Rahman'": 1,
#  " 'J Suchith'": 1,
#  " 'MEK Hussey'": 1,
#  " 'P Negi'": 1,
#  " 'A Nehra'": 1,
#  "'RV Uthappa'": 1,
#  " 'RN ten Doeschate'": 1,
#  " 'PP Chawla'": 1,
#  " 'M Morkel'": 1,
#  " 'UT Yadav'": 1,
#  "'V Sehwag'": 1,
#  " 'M Vohra'": 1,
#  " 'GJ Bailey'": 1,
#  " 'GJ Maxwell'": 1,
#  " 'Karanveer Singh'": 1,
#  " 'P Awana'": 1,
#  " 'CH Morris'": 1,
#  " 'AP Tare'": 1,
#  " 'R Dhawan'": 1,
#  "'MS Bisla'": 1,
#  " 'JH Kallis'": 1,
#  " 'LR Shukla'": 1,
#  " 'R Bhatia'": 1,
#  " 'B Lee'": 1,
#  " 'BW Hilfenhaus'": 1,
#  "'MA Agarwal'": 1,
#  " 'CH Gayle'": 1,
#  " 'LA Pomersbach'": 1,
#  " 'DL Vettori'": 1,
#  " 'A Mithun'": 1,
#  " 'J Syed Mohammad'": 1,
#  "'M Vijay'": 1,
#  " 'ML Hayden'": 1,
#  " 'S Anirudha'": 1,
#  "'S Dhawan'": 1,
#  " 'SR Tendulkar'": 1,
#  " 'AM Nayar'": 1,
#  " 'JP Duminy'": 1,
#  " 'CRD Fernando'": 1,
#  "'JH Kallis'": 1,
#  " 'RE van der Merwe'": 1,
#  " 'R Dravid'": 1,
#  " 'LRPL Taylor'": 1,
#  " 'MV Boucher'": 1,
#  " 'P Kumar'": 1,
#  " 'A Kumble'": 1,
#  "'AC Gilchrist'": 1,
#  " 'HH Gibbs'": 1,
#  " 'TL Suman'": 1,
#  " 'A Symonds'": 1,
#  " 'Y Venugopal Rao'": 1,
#  " 'AA Bilakhia'": 1,
#  " 'RJ Harris'": 1,
#  " 'Harmeet Singh'": 1,
#  " 'RP Singh'": 1,
#  "'PA Patel'": 1,
#  " 'S Vidyut'": 1,
#  " 'CK Kapugedera'": 1,
#  " 'MS Gony'": 1,
#  " 'M Ntini'": 1,
#  "'NK Patel'": 1,
#  " 'SA Asnodkar'": 1,
#  " 'Kamran Akmal'": 1,
#  " 'M Kaif'": 1,
#  " 'SK Warne'": 1,
#  " 'Sohail Tanvir'": 1,
#  " 'SK Trivedi'": 1,
#  " 'MM Patel'": 1}

# %% [markdown]
# ###`Q-9:` IPL Point Table
#
# Make a function `point_table` which take `season` as parameter and show points table in non-ascendng order of points and in ascending order of team name.
#
# For winning - 2 Ponits;
# For loosing - 0 Point
# For not result both team gets 1 points.
#
# Make dataframe which will have
# `TeamName` `MatchesPlayed` `MatchesWon` `NoResult` `Points`
# make `TeamName` as index.
#
# ```
# season parametr should be one of these->
# ['2022', '2021', '2020/21', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2009/10', '2009', '2007/08']
# ```

# %% [markdown]
# Output of two Top 2 in season 2022
# ```
# TeamName    MatchesPlayed	MatchesWon	NoResult	Points
#
# Gujarat Titans	    16	   12	       0	     24
# Rajasthan Royals	  17	   10	       0	     20
#
# ```

# %%
# code here
temp = df[(df['Season'] == '2015')]
temp.head(2)
# Out:
#          ID     City        Date Season  MatchNumber                Team1  \
# 433  829823  Kolkata  2015-05-24   2015        Final       Mumbai Indians
# 434  829821   Ranchi  2015-05-22   2015  Qualifier 2  Chennai Super Kings
#
#                            Team2                               Venue  \
# 433          Chennai Super Kings                        Eden Gardens
# 434  Royal Challengers Bangalore  JSCA International Stadium Complex
#
#               TossWinner TossDecision SuperOver          WinningTeam    WonBy  \
# 433  Chennai Super Kings        field         N       Mumbai Indians     Runs
# 434  Chennai Super Kings        field         N  Chennai Super Kings  Wickets
#
#      Margin method Player_of_Match  \
# 433    41.0    NaN       RG Sharma
# 434     3.0    NaN         A Nehra
#
#                                           Team1Players  \
# 433  ['LMP Simmons', 'PA Patel', 'RG Sharma', 'KA P...
# 434  ['DR Smith', 'MEK Hussey', 'F du Plessis', 'SK...
#
#                                           Team2Players          Umpire1  \
# 433  ['DR Smith', 'MEK Hussey', 'SK Raina', 'MS Dho...  HDPK Dharmasena
# 434  ['CH Gayle', 'V Kohli', 'AB de Villiers', 'Man...     AK Chaudhary
#
#             Umpire2                                            Players
# 433  RK Illingworth  ['LMP Simmons', 'PA Patel', 'RG Sharma', 'KA P...
# 434     CB Gaffaney  ['DR Smith', 'MEK Hussey', 'F du Plessis', 'SK...

# %%
points_table = pd.DataFrame()
points_table['No_of_matches'] = temp['Team1'].value_counts() + temp['Team2'].value_counts()
points_table
# Out:
#                              No_of_matches
# Chennai Super Kings                     17
# Delhi Capitals                          14
# Kolkata Knight Riders                   13
# Mumbai Indians                          16
# Punjab Kings                            14
# Rajasthan Royals                        14
# Royal Challengers Bangalore             16
# Sunrisers Hyderabad                     14

# %%
points_table['wins'] = temp['WinningTeam'].value_counts()
points_table
# Out:
#                              No_of_matches  wins
# Chennai Super Kings                     17    10
# Delhi Capitals                          14     5
# Kolkata Knight Riders                   13     7
# Mumbai Indians                          16    10
# Punjab Kings                            14     3
# Rajasthan Royals                        14     7
# Royal Challengers Bangalore             16     8
# Sunrisers Hyderabad                     14     7

# %%
s1 = temp[temp['WinningTeam'].isna()]['Team1'].value_counts()

# %%
s2 = temp[temp['WinningTeam'].isna()]['Team2'].value_counts()

# %%
points_table['No result'] = pd.concat([s1, s2]).groupby(level = 0).sum()
points_table['No result'] = points_table['No result'].fillna(0)

# %%
points_table
# Out:
#                              No_of_matches  wins  No result
# Chennai Super Kings                     17    10        0.0
# Delhi Capitals                          14     5        1.0
# Kolkata Knight Riders                   13     7        0.0
# Mumbai Indians                          16    10        0.0
# Punjab Kings                            14     3        0.0
# Rajasthan Royals                        14     7        1.0
# Royal Challengers Bangalore             16     8        2.0
# Sunrisers Hyderabad                     14     7        0.0

# %%
points_table['points'] = (points_table['wins'] * 2) + (points_table['No result'] * 1)
points_table
# Out:
#                              No_of_matches  wins  No result  points
# Chennai Super Kings                     17    10        0.0    20.0
# Delhi Capitals                          14     5        1.0    11.0
# Kolkata Knight Riders                   13     7        0.0    14.0
# Mumbai Indians                          16    10        0.0    20.0
# Punjab Kings                            14     3        0.0     6.0
# Rajasthan Royals                        14     7        1.0    15.0
# Royal Challengers Bangalore             16     8        2.0    18.0
# Sunrisers Hyderabad                     14     7        0.0    14.0

# %%
points_table = points_table.sort_values(by = 'points', ascending  = False)

# %%
def point_table(season):
    temp = (df[df['Season'] == season])
    points_table = pd.DataFrame()
    points_table['MatchesPlayed'] = temp['Team1'].value_counts() + temp['Team2'].value_counts()
    points_table['MatchesWon'] = temp['WinningTeam'].value_counts()
    points_table['NoResult'] = pd.concat([temp[temp['WinningTeam'].isna()]['Team1'].value_counts(), temp[temp['WinningTeam'].isna()]['Team2'].value_counts()]).groupby(level = 0).sum()
    points_table['NoResult'] = points_table['NoResult'].fillna(0)
    points_table['Points'] = (points_table['MatchesWon'] * 2) + (points_table['NoResult'] * 1)
    points_table = points_table.sort_values(by = 'Points', ascending  = False)
    return points_table
point_table('2022')
# Out:
#                              MatchesPlayed  MatchesWon  NoResult  Points
# Gujarat Titans                          16          12       0.0    24.0
# Rajasthan Royals                        17          10       0.0    20.0
# Lucknow Super Giants                    15           9       0.0    18.0
# Royal Challengers Bangalore             16           9       0.0    18.0
# Delhi Capitals                          14           7       0.0    14.0
# Punjab Kings                            14           7       0.0    14.0
# Kolkata Knight Riders                   14           6       0.0    12.0
# Sunrisers Hyderabad                     14           6       0.0    12.0
# Chennai Super Kings                     14           4       0.0     8.0
# Mumbai Indians                          14           4       0.0     8.0

# %% [markdown]
# ###`Q-10:` IPL Point Table cont.
# Extend the above IPL Point Table with an extra column as `SeasonPosition`
#
# Team below top 4 after sorting on `Points` and then on `TeamName` Will have same `SeasonPosition` as there rank. use rank function.
#
# Teams in Top four will have `SeasonPosition` as:
# ```
#     'Winner' - Team won final
#     'Runner' - Team lost Final
#     3 - Losing Team in Qualifier2
#     4 - Losing Team in Eliminator
# ```
#
# For changing value of pariticular cell use `df.at[row_index, col_label] = value`
#
# Output of two Top 2 in season 2022. Your result should have all teams.
# ```
# TeamName    MatchesPlayed	MatchesWon	NoResult	Points   SeasonPosition
#
# Gujarat Titans	    16	   12	       0	     24         Winner
# Rajasthan Royals	  17	   10	       0	     20         Runner
#
# ```
#
# Note: If you try to chnage value of view of any dataframe a warnig will be shown. To avoid it, make a copy of the dataframe you want to change in by `df.copy()`

# %%
# code here
points_table
# Out:
#                              No_of_matches  wins  No result  points
# Chennai Super Kings                     17    10        0.0    20.0
# Mumbai Indians                          16    10        0.0    20.0
# Royal Challengers Bangalore             16     8        2.0    18.0
# Rajasthan Royals                        14     7        1.0    15.0
# Kolkata Knight Riders                   13     7        0.0    14.0
# Sunrisers Hyderabad                     14     7        0.0    14.0
# Delhi Capitals                          14     5        1.0    11.0
# Punjab Kings                            14     3        0.0     6.0
