# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbs

# %%
iris = pd.read_csv('iris.csv')
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'])

# %%
# above contains all three species dat, if we want different color for each type, we first have to assign some numbering to each species
iris['Species'] = iris['Species'].replace({'Iris-setosa' : 0, 'Iris-versicolor' : 1, 'Iris-virginica' : 2})
iris['Species'].unique()
# Out:
# C:\Users\gpava\AppData\Local\Temp\ipykernel_8180\1562212676.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   iris['Species'] = iris['Species'].replace({'Iris-setosa' : 0, 'Iris-versicolor' : 1, 'Iris-virginica' : 2})
# array([0, 1, 2], dtype=int64)

# %%
plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'], c = iris['Species'])

# %%
# if we want to know which color represents which use
plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'], c = iris['Species'])
plt.colorbar()

# %%
# we can even specify different color maps according to matplotlib docs
plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'], c = iris['Species'], cmap = 'jet')
plt.colorbar()

# %%
# we can even specify the opacity by alpha value
plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'], c = iris['Species'], cmap = 'jet', alpha = 0.5)
plt.colorbar()

# %%
# we can even fix our desired size
plt.figure(figsize = (10, 10))
plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'], c = iris['Species'], cmap = 'jet', alpha = 0.9)
plt.colorbar()

# %%
batters = pd.read_csv('batter.csv')
batters.head(5)
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
# sampling 25 random from top 100 batsman
sample_df = batters.head(100).sample(25)
sample_df.head(5)
# Out:
#              batter  runs        avg  strike_rate
# 1          S Dhawan  6244  34.882682   122.840842
# 93  Harbhajan Singh   833  15.145455   130.974843
# 69       D Padikkal  1260  28.000000   119.205298
# 83     MC Henriques  1000  27.777778   124.843945
# 94       SO Hetmyer   831  30.777778   144.020797

# %%
plt.scatter(sample_df['avg'], sample_df['strike_rate'])

# %%
# the thing is in above we don't know which dot is which batsman, we can assign lables also 
x = [1, 2, 3, 4]
y = [5, 6, 7, 8]
plt.scatter(x, y)
# to assign lable, we have to do below
plt.text(1, 5, 'point 1')
plt.text(2, 6, 'point 2')
plt.text(3, 7, 'point 3')
plt.text(4, 8, 'point 4', fontdict = {'size' : 12, 'color' : 'brown'})
# Out:
# Text(4, 8, 'point 4')

# %%
plt.scatter(sample_df['avg'], sample_df['strike_rate'])

# %%
plt.scatter(sample_df['avg'], sample_df['strike_rate'])
for i in range(sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i], sample_df['strike_rate'].values[i], sample_df['batter'].values[i])

# %%
# we can even draw horizantal or vertical lines, like i want vertical line above 130 
plt.scatter(sample_df['avg'], sample_df['strike_rate'])
plt.axhline(130, color = 'red')
plt.axvline(30, color = 'red')
for i in range(sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i], sample_df['strike_rate'].values[i], sample_df['batter'].values[i])

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 1, sharex = True, figsize = (7, 5))

ax[0].scatter(sample_df['avg'], sample_df['strike_rate'])
ax[0].set_title('Avg vs Strike Rate')
ax[0].set_ylabel('Strike Rate')

ax[1].scatter(sample_df['avg'], sample_df['runs'])
ax[1].set_title('Avg vs Runs')
ax[1].set_ylabel('Runs')
ax[1].set_xlabel('Avg')
# Out:
# Text(0.5, 0, 'Avg')

# %%
# we can even plot 3d plots, for that first we have to create a figure and then add one subplot inside it 
fig = plt.figure(figsize = (10, 7))
ax = fig.add_subplot(1, 1, 1,projection = '3d')
ax.scatter3D(sample_df['avg'], sample_df['strike_rate'], sample_df['runs'], color = 'red')
ax.set_title('Batsman analysis')
ax.set_xlabel('Average')
ax.set_ylabel('Strike Rate')
ax.set_zlabel('Runs')
# Out:
# Text(0.5, 0, 'Runs')

# %%
# when it comes to 3d line, it will just join points the speciality is the line goes in depth wise also
x = [0, 1, 2]
y = [0, 1, 2]
z = [0, 1, 2]

fig = plt.figure(figsize = (10, 7))
ax = fig.add_subplot(1, 1, 1, projection = '3d')
ax.scatter3D(x, y, z, s = [100, 100, 100])
ax.plot3D(x, y, z, color = 'red')

# %%
# plotting 3d surface plots
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)

X,  Y = np.meshgrid(x, y)
z = X**2 + Y**2

fig = plt.figure(figsize = (11, 7))
ax = fig.add_subplot(1, 1, 1, projection = '3d')
# colormap represents where values are higher and lower
# for 3d plots first we have to store it in seperate variable then we have to pass that into colorbar
p = ax.plot_surface(X, Y, z, cmap = 'viridis')
fig.colorbar(p)

# %%
# contour plots means cutting the surface 
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)
X, Y = np.meshgrid(x, y)
z = X**2 + Y**2

fig = plt.figure(figsize = (10, 7))
ax1 = fig.add_subplot(projection = '3d')
a = ax1.plot_surface(X, Y, z, cmap = 'viridis')
fig.colorbar(a)

fig = plt.figure(figsize = (10, 7))
ax2 = fig.add_subplot()
b = ax2.contour(X, Y, z, cmap = 'viridis')
fig.colorbar(b)

fig = plt.figure(figsize = (10, 7))
ax3 = fig.add_subplot()
c = ax3.contourf(X, Y, z, cmap = 'viridis')
fig.colorbar(c)

# %%
# plotting total no.of sixes in each over for each ball in ipl
deliveries = pd.read_csv('IPL_Ball_by_Ball_2008_2022.csv')
deliveries
# Out:
#              ID  innings  overs  ballnumber       batter          bowler  \
# 0       1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1       1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2       1312200        1      0           3   JC Buttler  Mohammed Shami
# 3       1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4       1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...         ...      ...    ...         ...          ...             ...
# 225949   335982        2     14           5      P Kumar        I Sharma
# 225950   335982        2     14           6     SB Joshi        I Sharma
# 225951   335982        2     14           7      P Kumar        I Sharma
# 225952   335982        2     15           1     SB Joshi       LR Shukla
# 225953   335982        2     15           2     SB Joshi       LR Shukla
#
#         non-striker extra_type  batsman_run  extras_run  total_run  \
# ...

# %%
sixes = deliveries[
                    (deliveries['ballnumber'].isin([1, 2, 3, 4, 5, 6])) &
                    (deliveries['batsman_run'] == 6)
]
sixes
# Out:
#              ID  innings  overs  ballnumber       batter             bowler  \
# 16      1312200        1      2           5  YBK Jaiswal     Mohammed Shami
# 22      1312200        1      3           5  YBK Jaiswal         Yash Dayal
# 103     1312200        1     17           2     TA Boult      R Sai Kishore
# 107     1312200        1     17           6     OC McCoy      R Sai Kishore
# 142     1312200        2      3           5      MS Wade  M Prasidh Krishna
# ...         ...      ...    ...         ...          ...                ...
# 225848   335982        1     19           2  BB McCullum            P Kumar
# 225852   335982        1     19           6  BB McCullum            P Kumar
# 225882   335982        2      4           4    JH Kallis         AB Agarkar
# 225932   335982        2     12           1      P Kumar          LR Shukla
# 225944   335982        2     13           6      P Kumar         SC Ganguly
#
# ...

# %%
grid = sixes.pivot_table(index = 'overs', columns = 'ballnumber', values = 'batsman_run', aggfunc = 'count')

# %%
# for heatmap
plt.figure(figsize = (10, 5))
plt.imshow(grid)
plt.colorbar()

# %%
# we can plot graphs even more easily by using plot method in pandas but maynot be able to do that much customization as in matplotlib
tips = sbs.load_dataset('tips')
tips['size'] = tips['size'] * 20

# %%
tips.plot(kind = 'scatter', x = 'total_bill', y = 'tip', title = 'Cost analysis', c = 'sex', cmap = 'viridis', s = 'size')
# Out:
# <Axes: title={'center': 'Cost analysis'}, xlabel='total_bill', ylabel='tip'>

# %%
stocks = pd.read_csv('https://raw.githubusercontent.com/m-mehdi/pandas_tutorials/main/weekly_stocks.csv')
stocks.head()
# Out:
#          Date        MSFT          FB        AAPL
# 0  2021-05-24  249.679993  328.730011  124.610001
# 1  2021-05-31  250.789993  330.350006  125.889999
# 2  2021-06-07  257.890015  331.260010  127.349998
# 3  2021-06-14  259.429993  329.660004  130.460007
# 4  2021-06-21  265.019989  341.369995  133.110001

# %%
stocks[['MSFT', 'Date']].plot(kind = 'line', x = 'Date')
# Out:
# <Axes: xlabel='Date'>

# %%
# we can even plot for all at once very easy
stocks.plot(kind = 'line', x = 'Date')
# Out:
# <Axes: xlabel='Date'>

# %%
tips.groupby('sex')['total_bill'].sum().plot(kind = 'bar')
# Out:
# C:\Users\gpava\AppData\Local\Temp\ipykernel_8180\177728305.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby('sex')['total_bill'].sum().plot(kind = 'bar')
# <Axes: xlabel='sex'>

# %%
# we can even plot stacked and side by side bar charts very easily here compared to matplotlib
batters = pd.read_csv('batsman_season_record.csv')
batters
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
batters.plot(kind = 'bar', x = 'batsman')
# Out:
# <Axes: xlabel='batsman'>

# %%
batters.plot(kind = 'bar', stacked = True, x = 'batsman')
# Out:
# <Axes: xlabel='batsman'>

# %%
# we can even plot subplots
stocks.plot(kind = 'line', x = 'Date', subplots = True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)
