# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('netflix_titles.csv')

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
df.sample(5)
# Out:
#      show_id   type                              title  \
# 5121   s5122  Movie              Christmas Inheritance
# 4825   s4826  Movie                       Lust Stories
# 8634   s8635  Movie                  Troy: The Odyssey
# 6260   s6261  Movie  Bean: The Ultimate Disaster Movie
# 6738   s6739  Movie                            Fanatic
#
#                                                director  \
# 5121                                    Ernie Barbarash
# 4825  Zoya Akhtar, Karan Johar, Anurag Kashyap, Diba...
# 8634                                       Tekin Girgin
# 6260                                          Mel Smith
# 6738                                     Keith L. Smith
#
#                                                    cast  \
# 5121  Eliza Taylor, Jake Lacy, Andie MacDowell, Mich...
# 4825  Vicky Kaushal, Bhumi Pednekar, Radhika Apte, N...
# 8634  Dylan Vox, Lara Heller, Hachem Hicham, David G...
# 6260  Rowan Atkinson, Peter MacNicol, John Mills, Pa...
# 6738  Denyce Lawton, Hosea Chanchez, Michelle Mitche...
#
#                             country         date_added  release_year rating  \
# 5121                  United States  December 15, 2017          2017   TV-G
# 4825                          India      June 15, 2018          2018  TV-MA
# 8634                  United States     March 12, 2018          2017  TV-MA
# 6260  United Kingdom, United States     August 1, 2018          1997  PG-13
# 6738                  United States    August 24, 2019          2019  TV-14
#
#      duration                                      listed_in  \
# 5121  105 min  Dramas, International Movies, Romantic Movies
# 4825  121 min         Comedies, Dramas, International Movies
# 8634   90 min                             Action & Adventure
# 6260   89 min                 Comedies, International Movies
# 6738   91 min                                      Thrillers
#
#                                             description
# 5121  To inherit her father's company, socialite Ell...
# 4825  In the companion to 2013's "Bombay Talkies," f...
# 8634  Starting with the Trojan Horse attack, this mo...
# 6260  Disaster-prone Mr. Bean is sent to Los Angeles...
# 6738  When a successful young rap star has an affair...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df['type'] = df['type'].astype('category')
df['country'] = df['country'].astype('category')
df['release_year'] = df['release_year'].astype('category')
df['rating'] = df['rating'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   category
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   category
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   category
#  8   rating        8803 non-null   category
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: category(4), object(8)
# memory usage: 619.0+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.corr(numeric_only = True)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
sns.countplot(data = df, x = 'type')
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
df['rating'].value_counts().plot(kind = 'pie', autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>
