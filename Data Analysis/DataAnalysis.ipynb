# %%
#reading different types of csv files

# %%
import numpy as np
import pandas as pd

# %%
# importing from the machine
df = pd.read_csv('aug_train.csv')
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
# to read files by using url
import requests
import pandas as pd
from io import StringIO

url = "https://raw.githubusercontent.com/campusx-official/100-days-of-machine-learning/main/day15%20-%20working%20with%20csv%20files/IPL%20Matches%202008-2020.csv"

response = requests.get(url)
response.raise_for_status()

df = pd.read_csv(StringIO(response.text))
df.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
# to read tsv files
df = pd.read_csv('movie_titles_metadata.tsv', sep = '\t')
df
# Out:
#        m0  10 things i hate about you  1999  6.90     62847  \
# 0      m1  1492: conquest of paradise  1992   6.2   10421.0
# 1      m2                  15 minutes  2001   6.1   25854.0
# 2      m3       2001: a space odyssey  1968   8.4  163227.0
# 3      m4                     48 hrs.  1982   6.9   22289.0
# 4      m5           the fifth element  1997   7.5  133756.0
# ..    ...                         ...   ...   ...       ...
# 611  m612                    watchmen  2009   7.8  135229.0
# 612  m613                         xxx  2002   5.6   53505.0
# 613  m614                       x-men  2000   7.4  122149.0
# 614  m615          young frankenstein  1974   8.0   57618.0
# 615  m616                   zulu dawn  1979   6.4    1911.0
#
#                                   ['comedy' 'romance']
# 0          ['adventure' 'biography' 'drama' 'history']
# 1                ['action' 'crime' 'drama' 'thriller']
# 2                     ['adventure' 'mystery' 'sci-fi']
# ...

# %%
# above first row became header, if we want columns seperately we can also do this
df = pd.read_csv('movie_titles_metadata.tsv', sep = '\t', names = ['ser', 'name', 'year', 'rating', 'votes', 'genre'])
df.head(3)
# Out:
#   ser                        name  year  rating    votes  \
# 0  m0  10 things i hate about you  1999     6.9  62847.0
# 1  m1  1492: conquest of paradise  1992     6.2  10421.0
# 2  m2                  15 minutes  2001     6.1  25854.0
#
#                                          genre
# 0                         ['comedy' 'romance']
# 1  ['adventure' 'biography' 'drama' 'history']
# 2        ['action' 'crime' 'drama' 'thriller']

# %%
df = pd.read_csv('aug_train.csv')
df.head(3)
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM        >20          NaN          NaN            1
# 1             STEM         15        50-99      Pvt Ltd           >4
# 2             STEM          5          NaN          NaN        never
#
#    training_hours  target
# 0              36     1.0
# 1              47     0.0
# 2              83     0.0

# %%
# we can change the index based on what we want
df = pd.read_csv('aug_train.csv', index_col = 'enrollee_id')
df.head(3)
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
#
#             enrolled_university education_level major_discipline experience  \
# enrollee_id
# 8949              no_enrollment        Graduate             STEM        >20
# 29725             no_enrollment        Graduate             STEM         15
# 11561          Full time course        Graduate             STEM          5
#
#             company_size company_type last_new_job  training_hours  target
# enrollee_id
# 8949                 NaN          NaN            1              36     1.0
# 29725              50-99      Pvt Ltd           >4              47     0.0
# 11561                NaN          NaN        never              83     0.0

# %%
df = pd.read_csv('test.csv')
df.head(3)
# Out:
#    Unnamed: 0   Unnamed: 1 Unnamed: 2              Unnamed: 3 Unnamed: 4  \
# 0           0  enrollee_id       city  city_development_index     gender
# 1           1        29725    city_40                   0.776       Male
# 2           2        11561    city_21                   0.624        NaN
#
#                Unnamed: 5           Unnamed: 6       Unnamed: 7  \
# 0     relevent_experience  enrolled_university  education_level
# 1  No relevent experience        no_enrollment         Graduate
# 2  No relevent experience     Full time course         Graduate
#
#          Unnamed: 8  Unnamed: 9   Unnamed: 10   Unnamed: 11   Unnamed: 12  \
# 0  major_discipline  experience  company_size  company_type  last_new_job
# 1              STEM          15         50-99       Pvt Ltd            >4
# 2              STEM           5           NaN           NaN         never
#
#       Unnamed: 13 Unnamed: 14
# 0  training_hours      target
# 1              47           0
# ...

# %%
# above actaully 1st row is the header column, but somehow a data error , we can set this by
df = pd.read_csv('test.csv', header = 1)
df.head(3)
# Out:
#    0  enrollee_id      city  city_development_index gender  \
# 0  1        29725   city_40                   0.776   Male
# 1  2        11561   city_21                   0.624    NaN
# 2  3        33241  city_115                   0.789    NaN
#
#       relevent_experience enrolled_university education_level  \
# 0  No relevent experience       no_enrollment        Graduate
# 1  No relevent experience    Full time course        Graduate
# 2  No relevent experience                 NaN        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM         15        50-99      Pvt Ltd           >4
# 1             STEM          5          NaN          NaN        never
# 2  Business Degree         <1          NaN      Pvt Ltd        never
#
#    training_hours  target
# 0              47       0
# 1              83       0
# 2              52       1

# %%
df = pd.read_csv('aug_train.csv')
df.head(3)
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM        >20          NaN          NaN            1
# 1             STEM         15        50-99      Pvt Ltd           >4
# 2             STEM          5          NaN          NaN        never
#
#    training_hours  target
# 0              36     1.0
# 1              47     0.0
# 2              83     0.0

# %%
# sometimes we don't want to use all columns and we can specify them during starting itself only
df = pd.read_csv('aug_train.csv', usecols = ['enrollee_id', 'gender', 'education_level'])
df.head(3)
# Out:
#    enrollee_id gender education_level
# 0         8949   Male        Graduate
# 1        29725   Male        Graduate
# 2        11561    NaN        Graduate

# %%
# let's say we want only one row
df = pd.read_csv('aug_train.csv', usecols = ['gender'])
df.head(3)
# Out:
#   gender
# 0   Male
# 1   Male
# 2    NaN

# %%
# we can even skiprows if we want
df = pd.read_csv('aug_train.csv', skiprows = [0, 3])
df
# Out:
#         8949  city_103   0.92  Male  Has relevent experience  \
# 0      29725   city_40  0.776  Male   No relevent experience
# 1      33241  city_115  0.789   NaN   No relevent experience
# 2        666  city_162  0.767  Male  Has relevent experience
# 3      21651  city_176  0.764   NaN  Has relevent experience
# 4      28806  city_160  0.920  Male  Has relevent experience
# ...      ...       ...    ...   ...                      ...
# 19151   7386  city_173  0.878  Male   No relevent experience
# 19152  31398  city_103  0.920  Male  Has relevent experience
# 19153  24576  city_103  0.920  Male  Has relevent experience
# 19154   5756   city_65  0.802  Male  Has relevent experience
# 19155  23834   city_67  0.855   NaN   No relevent experience
#
#           no_enrollment        Graduate             STEM  >20 Unnamed: 9  \
# 0         no_enrollment        Graduate             STEM   15      50-99
# 1                   NaN        Graduate  Business Degree   <1        NaN
# ...

# %%
# we can even limit our rows
df = pd.read_csv('aug_train.csv', nrows = 100)
df.shape
# Out:
# (100, 14)

# %%
df = pd.read_csv('zomato.csv')
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df = pd.read_csv('zomato.csv')
#       2 df.head(3)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
# the encoding for above fiule is not utf 8, but it is latin-1
df = pd.read_csv('zomato.csv', encoding = 'latin-1')
df.head(3)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# ...

# %%
df= pd.read_csv('aug_train.csv')
df['target'].head(3)
# Out:
# 0    1.0
# 1    0.0
# 2    0.0
# Name: target, dtype: float64

# %%
# actually the above column contains only integers but it is taking as float, we can convert this while reading the file itself
df = pd.read_csv('aug_train.csv', dtype = {'target' : np.int8})
df['target'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 19158 entries, 0 to 19157
# Series name: target
# Non-Null Count  Dtype
# --------------  -----
# 19158 non-null  int8
# dtypes: int8(1)
# memory usage: 18.8 KB

# %%
df = pd.read_csv('IPL Matches 2008-2020.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
# normally max times date values are stored as strings, but we can parse them as dates while loading the data itself
df = pd.read_csv('IPL Matches 2008-2020.csv', parse_dates = ['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    datetime64[ns]
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
# we can apply some functions to the columns we want first only
df = pd.read_csv('IPL Matches 2008-2020.csv')
df.head(3)
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
#
#                          team1                  team2  \
# 0  Royal Challengers Bangalore  Kolkata Knight Riders
# 1              Kings XI Punjab    Chennai Super Kings
# 2             Delhi Daredevils       Rajasthan Royals
#
#                    toss_winner toss_decision                 winner   result  \
# 0  Royal Challengers Bangalore         field  Kolkata Knight Riders     runs
# 1          Chennai Super Kings           bat    Chennai Super Kings     runs
# ...

# %%
# suppose we want to rename the column team1 where if name is Rcb full form, we want rcb short form
def rename(name):
    if (name == 'Royal Challengers Bangalore'):
        return 'RCB'
    else:
        return name

df = pd.read_csv('IPL Matches 2008-2020.csv', converters = {'team1': rename, 'team2': rename, 'winner': rename, 'toss_winner' : rename})
df.head(3)
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
#
#               team1                  team2          toss_winner toss_decision  \
# 0               RCB  Kolkata Knight Riders                  RCB         field
# 1   Kings XI Punjab    Chennai Super Kings  Chennai Super Kings           bat
# 2  Delhi Daredevils       Rajasthan Royals     Rajasthan Royals           bat
#
#                   winner   result  result_margin eliminator method    umpire1  \
# 0  Kolkata Knight Riders     runs          140.0          N    NaN  Asad Rauf
# ...

# %%
df = pd.read_csv('aug_train.csv')
df.head(3)
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM        >20          NaN          NaN            1
# 1             STEM         15        50-99      Pvt Ltd           >4
# 2             STEM          5          NaN          NaN        never
#
#    training_hours  target
# 0              36     1.0
# 1              47     0.0
# 2              83     0.0

# %%
# sometimes null values are not clearly visible like cells will be empty or hyphen like that, we can specify what kind of values
# should be considered as null vlaues before hand only, here for ex considering male as nan value in gender column
df = pd.read_csv('aug_train.csv', na_values = ['Male'])
df.head(3)
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920    NaN
# 1        29725   city_40                   0.776    NaN
# 2        11561   city_21                   0.624    NaN
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
#
#   major_discipline experience company_size company_type last_new_job  \
# 0             STEM        >20          NaN          NaN            1
# 1             STEM         15        50-99      Pvt Ltd           >4
# 2             STEM          5          NaN          NaN        never
#
#    training_hours  target
# 0              36     1.0
# 1              47     0.0
# 2              83     0.0

# %%
# we can even divide our data into chunks if we want to operate large datasets
dfs = pd.read_csv('aug_train.csv', chunksize = 5000)

# %%
for chunk in dfs:
    print(chunk.shape)
# Out:
# (5000, 14)
# (5000, 14)
# (5000, 14)
# (4158, 14)
