# %%
# working with json and sql files

# %%
import pandas as pd
import numpy as np

# %%
# reading a json file
df = pd.read_json('train.json')
df.head(3)
# Out:
#       id      cuisine                                        ingredients
# 0  10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...

# %%
# we can also directly read from url 
df = pd.read_json('https://api.exchangerate-api.com/v4/latest/INR')
df.head(3)
# Out:
#                              provider  \
# INR  https://www.exchangerate-api.com
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# INR  https://www.exchangerate-api.com/docs/free
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
#
#                                       terms base       date  \
# INR  https://www.exchangerate-api.com/terms  INR 2026-04-12
# AED  https://www.exchangerate-api.com/terms  INR 2026-04-12
# AFN  https://www.exchangerate-api.com/terms  INR 2026-04-12
#
#      time_last_updated   rates
# INR         1775952002  1.0000
# AED         1775952002  0.0395
# AFN         1775952002  0.6940

# %%
#!pip install mysql.connector
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#       --------------------------------------- 0.3/11.9 MB ? eta -:--:--
#       --------------------------------------- 0.3/11.9 MB ? eta -:--:--
#       --------------------------------------- 0.3/11.9 MB ? eta -:--:--
#       --------------------------------------- 0.3/11.9 MB ? eta -:--:--
#       --------------------------------------- 0.3/11.9 MB ? eta -:--:--
#      - ------------------------------------- 0.5/11.9 MB 270.8 kB/s eta 0:00:42
#      - ------------------------------------- 0.5/11.9 MB 270.8 kB/s eta 0:00:42
#      -- ------------------------------------ 0.8/11.9 MB 349.5 kB/s eta 0:00:32
#      -- ------------------------------------ 0.8/11.9 MB 349.5 kB/s eta 0:00:32
# ...

# %%
#!python.exe -m pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
# ...

# %%
#import mysql.connector
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import mysql.connector
#
# ModuleNotFoundError: No module named 'mysql'

# %%
#fixin above issue
#import sys
#sys.executable
# Out:
# 'C:\\Users\\gpava\\anaconda3\\python.exe'

# %%
#!{sys.executable} -m pip install mysql-connector-python
# Out:
# ...
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.5 MB 145.2 kB/s eta 0:01:54
#    ---------------------------------------- 0.0/16.5 MB 145.2 kB/s eta 0:01:54
#    ---------------------------------------- 0.1/16.5 MB 348.6 kB/s eta 0:00:48
#    ---------------------------------------- 0.2/16.5 MB 482.7 kB/s eta 0:00:34
#    ---------------------------------------- 0.2/16.5 MB 593.2 kB/s eta 0:00:28
#     --------------------------------------- 0.2/16.5 MB 550.0 kB/s eta 0:00:30
# ...

# %%
#import mysql.connector

# %%
#conn = mysql.connector.connect(host = 'localhost', user = 'root', password = 'Pk@dhfm5048', database = 'world')

# %%
#df = pd.read_sql_query('select * from city', conn)
#df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_sql_query('select * from city', conn)
#       2 df
#
# NameError: name 'conn' is not defined

# %%
#!pip uninstall mysql.connector -y
# Out:
# Found existing installation: mysql-connector 2.2.9
# Uninstalling mysql-connector-2.2.9:
#   Successfully uninstalled mysql-connector-2.2.9

# %%
#!pip uninstall mysql-connector -y
# Out:
# WARNING: Skipping mysql-connector as it is not installed.

# %%
#!pip uninstall mysql-connector-python -y
# Out:
# WARNING: Skipping mysql-connector-python as it is not installed.

# %%
#!pip install mysql_connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/16.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/16.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/16.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/16.5 MB 508.0 kB/s eta 0:00:32
#    - -------------------------------------- 0.5/16.5 MB 508.0 kB/s eta 0:00:32
#    - -------------------------------------- 0.5/16.5 MB 508.0 kB/s eta 0:00:32
# ...

# %%
import mysql.connector
print('success')
# Out:
# success

# %%
conn = mysql.connector.connect(host = '127.0.0.1', user = 'root', password = 'Pk@dhfm5048', auth_plugin = 'caching_sha2_password')
print('connected')
